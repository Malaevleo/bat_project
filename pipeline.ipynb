# %% [markdown]
# **MMSEQS2**

# %% [markdown]
# mmseqs/bin/mmseqs easy-search impairment_of_the_mitochondrial_integrity_and_biogenesis_genes.fasta realmergedprots_noen.faa mitimpair_noen.m8 -c 0.2 tmp --min-seq-id 0.3 --alt-ali 25

# %%
import pandas as pd
columns = ["qseqid", "sseqid", "pident", "length", "mismatch", "gapopen", 
           "qstart", "qend", "sstart", "send", "evalue", "bitscore"]

df = pd.read_csv('batstring.m8', sep='\t', names=columns)
print(df.head())
# Out:
#                      qseqid            sseqid  pident  length  mismatch  \
# 0  59463.ENSMLUP00000016363  mlXP_023610807.1   0.961     389        15
# 1  59463.ENSMLUP00000016363  mmXP_036164646.1   0.953     387        18
# 2  59463.ENSMLUP00000016363  mdXP_059550832.1   0.948     387        20
# 3  59463.ENSMLUP00000016363  pkXP_036265305.1   0.935     387        25
# 4  59463.ENSMLUP00000016363  moXP_036135537.1   0.912     387        34
#
#    gapopen  qstart  qend  sstart  send         evalue  bitscore
# 0        0       1   387       1   389  3.536000e-254       780
# 1        0       1   387       1   387  1.551000e-252       775
# 2        0       1   387       1   387  9.320000e-251       770
# 3        0       1   387       1   386  1.339000e-244       752
# 4        0       1   387       1   387  1.546000e-239       738

# %%
best_matches = pd.DataFrame()

bat_prefixes = ['rf', 'dr', 'ra', 'pv', 'pg', 'pa', 'pk', 'ph', 'pd', 'mm', 'ml', 'mb', 'mo', 'md', 'sb', 'ef', 'aj', 'pn', 'en']

for prefix in bat_prefixes:

    bat_matches = df[df['sseqid'].str.startswith(prefix)]

    best_bat_matches = bat_matches.loc[bat_matches.groupby('qseqid')['pident'].idxmax()]

    best_matches = pd.concat([best_matches, best_bat_matches], ignore_index=True)


print(best_matches)
# Out:
#                        qseqid            sseqid  pident  length  mismatch  \
# 0    59463.ENSMLUP00000000083  rfXP_032946134.1   0.964     284        10
# 1    59463.ENSMLUP00000001427  rfXP_032943217.1   0.931     189        13
# 2    59463.ENSMLUP00000001789  rfXP_032971332.1   0.959     524        21
# 3    59463.ENSMLUP00000002616  rfXP_032990906.1   0.929     427        30
# 4    59463.ENSMLUP00000002847  rfXP_032969289.1   0.807     209        39
# ..                        ...               ...     ...     ...       ...
# 488  59463.ENSMLUP00000014213    pnCAK6441801.1   0.995     660         3
# 489  59463.ENSMLUP00000016071    pnCAK6440610.1   0.835     462        75
# 490  59463.ENSMLUP00000016363    pnCAK6444154.1   0.975     248         6
# 491  59463.ENSMLUP00000016529    pnCAK6437761.1   0.912     663        58
# 492  59463.ENSMLUP00000022559    pnCAK6446407.1   0.980     157         3
#
#      gapopen  qstart  qend  sstart  send         evalue  bitscore
# 0          0       1   284      94   377  1.343000e-183       571
# 1          0      24   212       1   189  1.609000e-118       379
# 2          0       1   524       1   524   0.000000e+00      1043
# 3          0       1   427       1   427  4.627000e-270       828
# 4          0       1   209       1   203  3.690000e-105       340
# ..       ...     ...   ...     ...   ...            ...       ...
# 488        0       1   660      21   680   0.000000e+00      1330
# 489        0       1   462       1   453  3.428000e-241       747
# 490        0     140   387       1   248  5.966000e-157       499
# 491        0       1   663       1   663   0.000000e+00      1269
# 492        0       1   157     226   382   4.836000e-97       314
#
# [493 rows x 12 columns]

# %%
best_matches.to_csv('batstring_bestmatches.txt', sep='\t', index=False)

# %%
best_matches['bat_prefix'] = best_matches['sseqid'].str[:2]

# Group by 'qseqid' and count unique 'bat_prefix' values for each human protein
bat_counts_per_human = best_matches.groupby('qseqid')['bat_prefix'].nunique()

# Display the counts
print(bat_counts_per_human)
# Out:
# qseqid
# 59463.ENSMLUP00000000083    17
# 59463.ENSMLUP00000001427    17
# 59463.ENSMLUP00000001789    17
# 59463.ENSMLUP00000002616    17
# 59463.ENSMLUP00000002847    17
# 59463.ENSMLUP00000003315    17
# 59463.ENSMLUP00000003322    17
# 59463.ENSMLUP00000004009    17
# 59463.ENSMLUP00000004202    17
# 59463.ENSMLUP00000005054    17
# 59463.ENSMLUP00000005277    17
# 59463.ENSMLUP00000005366    17
# 59463.ENSMLUP00000005595    17
# 59463.ENSMLUP00000008027    17
# 59463.ENSMLUP00000009180    17
# 59463.ENSMLUP00000009404    17
# 59463.ENSMLUP00000010380    17
# 59463.ENSMLUP00000011160    17
# 59463.ENSMLUP00000011196    17
# 59463.ENSMLUP00000011227    17
# 59463.ENSMLUP00000011717    17
# 59463.ENSMLUP00000012090    17
# 59463.ENSMLUP00000013453    17
# 59463.ENSMLUP00000013787    17
# 59463.ENSMLUP00000014213    17
# 59463.ENSMLUP00000016071    17
# 59463.ENSMLUP00000016363    17
# 59463.ENSMLUP00000016529    17
# 59463.ENSMLUP00000022559    17
# Name: bat_prefix, dtype: int64

# %%
qseqids_less_than = bat_counts_per_human[bat_counts_per_human < 17].index.tolist()
print("qseqids with less than 17 bat matches:", qseqids_less_than)
print(len(qseqids_less_than))
# Out:
# qseqids with less than 17 bat matches: []
# 0

# %%
best_matches['pident'].median()
# Out:
# 0.933

# %% [markdown]
# PAIRED FASTA GENERATION

# %%
from Bio import SeqIO
import pandas as pd
import os


# File path
bat_fasta_file = "realmergedprots_noen.faa"  # FASTA file containing bat protein sequences
blast_results_file = "batstring_bestmatches.txt"  # Should contain the best_matches DataFrame
output_dir = "batstring_paired"  # Directory to store per-gene FASTA files

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Function to load sequences while handling duplicates
def load_fasta_with_duplicates(fasta_file):
    sequences = {}
    for record in SeqIO.parse(fasta_file, "fasta"):
        if record.id not in sequences:
            sequences[record.id] = record
        else:
            print(f"Duplicate ID found: {record.id}, ignoring this entry.")
    return sequences

# Load bat sequences
bat_sequences = load_fasta_with_duplicates(bat_fasta_file)

# Load best_matches DataFrame
blast_df = pd.read_csv(blast_results_file, sep="\t")

# Process each human gene and its associated bat genes
for qseqid, group in blast_df.groupby("qseqid"):
    output_file = os.path.join(output_dir, f"{qseqid}_bat_only.fasta")
    
    with open(output_file, "w") as output_fasta:
        # Write only aligned bat protein sequences
        for _, row in group.iterrows():
            sseqid_full = row["sseqid"]
            prefix = sseqid_full[:2]
            sseqid = sseqid_full

            if sseqid in bat_sequences:
                sseq = bat_sequences[sseqid].seq
                sdesc = bat_sequences[sseqid].description

                # Note the ID source based on prefix
                if prefix == "pn" or prefix == 'en':
                    id_source = "GenBank"
                else:
                    id_source = "RefSeq"

                # Write the bat protein sequence
                output_fasta.write(f">{sseqid} {sdesc} [{id_source}]\n{sseq}\n")
            else:
                print(f"SseqID {sseqid} not found in bat proteome.")

    print(f"Bat-only paired sequences for {qseqid} written to {output_file}")

print(f"All bat-only paired sequences written to directory: {output_dir}")
# Out:
# Bat-only paired sequences for 59463.ENSMLUP00000000083 written to batstring_paired\59463.ENSMLUP00000000083_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000001427 written to batstring_paired\59463.ENSMLUP00000001427_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000001789 written to batstring_paired\59463.ENSMLUP00000001789_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000002616 written to batstring_paired\59463.ENSMLUP00000002616_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000002847 written to batstring_paired\59463.ENSMLUP00000002847_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000003315 written to batstring_paired\59463.ENSMLUP00000003315_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000003322 written to batstring_paired\59463.ENSMLUP00000003322_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000004009 written to batstring_paired\59463.ENSMLUP00000004009_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000004202 written to batstring_paired\59463.ENSMLUP00000004202_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000005054 written to batstring_paired\59463.ENSMLUP00000005054_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000005277 written to batstring_paired\59463.ENSMLUP00000005277_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000005366 written to batstring_paired\59463.ENSMLUP00000005366_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000005595 written to batstring_paired\59463.ENSMLUP00000005595_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000008027 written to batstring_paired\59463.ENSMLUP00000008027_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000009180 written to batstring_paired\59463.ENSMLUP00000009180_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000009404 written to batstring_paired\59463.ENSMLUP00000009404_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000010380 written to batstring_paired\59463.ENSMLUP00000010380_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000011160 written to batstring_paired\59463.ENSMLUP00000011160_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000011196 written to batstring_paired\59463.ENSMLUP00000011196_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000011227 written to batstring_paired\59463.ENSMLUP00000011227_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000011717 written to batstring_paired\59463.ENSMLUP00000011717_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000012090 written to batstring_paired\59463.ENSMLUP00000012090_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000013453 written to batstring_paired\59463.ENSMLUP00000013453_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000013787 written to batstring_paired\59463.ENSMLUP00000013787_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000014213 written to batstring_paired\59463.ENSMLUP00000014213_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000016071 written to batstring_paired\59463.ENSMLUP00000016071_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000016363 written to batstring_paired\59463.ENSMLUP00000016363_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000016529 written to batstring_paired\59463.ENSMLUP00000016529_bat_only.fasta
# Bat-only paired sequences for 59463.ENSMLUP00000022559 written to batstring_paired\59463.ENSMLUP00000022559_bat_only.fasta
# All bat-only paired sequences written to directory: batstring_paired

# %%
from Bio import SeqIO
import pandas as pd
import os

# File paths
bat_fasta_file = "realmergedprots_filtered.faa"  # FASTA file containing bat protein sequences
blast_results_file = "housekeeping_bestmatches.txt"  # Should contain the best_matches DataFrame
output_dir = "housekeeping_paired"  # Directory to store per-gene FASTA files

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Function to load sequences while handling duplicates
def load_fasta_with_duplicates(fasta_file):
    sequences = {}
    for record in SeqIO.parse(fasta_file, "fasta"):
        if record.id not in sequences:
            sequences[record.id] = record
        else:
            print(f"Duplicate ID found: {record.id}, ignoring this entry.")
    return sequences

# Load bat sequences
bat_sequences = load_fasta_with_duplicates(bat_fasta_file)

# Load best_matches DataFrame
blast_df = pd.read_csv(blast_results_file, sep="\t")

# Process each human gene and its associated bat genes
for qseqid, group in blast_df.groupby("qseqid"):
    output_file = os.path.join(output_dir, f"{qseqid}_bat_only.fasta")
    
    with open(output_file, "w") as output_fasta:
        # Write only aligned bat protein sequences
        for _, row in group.iterrows():
            sseqid = row["sseqid"]  # Use sseqid directly as the key for lookup

            if sseqid in bat_sequences:
                sseq = bat_sequences[sseqid].seq
                sdesc = bat_sequences[sseqid].description

                # Write the bat protein sequence without altering the label
                output_fasta.write(f">{sseqid} {sdesc}\n{sseq}\n")
            else:
                print(f"SseqID {sseqid} not found in bat proteome.")

    print(f"Bat-only paired sequences for {qseqid} written to {output_file}")

print(f"All bat-only paired sequences written to directory: {output_dir}")
# Out:
# Bat-only paired sequences for P00558 written to housekeeping_paired\P00558_bat_only.fasta
# Bat-only paired sequences for P04406 written to housekeeping_paired\P04406_bat_only.fasta
# Bat-only paired sequences for P05388 written to housekeeping_paired\P05388_bat_only.fasta
# Bat-only paired sequences for P60709 written to housekeeping_paired\P60709_bat_only.fasta
# Bat-only paired sequences for P62277 written to housekeeping_paired\P62277_bat_only.fasta
# All bat-only paired sequences written to directory: housekeeping_paired

# %% [markdown]
# Then MSA in command line (MAFFT) OPTIONAL

# %% [markdown]
# Nucleotide file generation

# %%
import os
from Bio import SeqIO

# File paths
nucleotide_fasta = "mergedprotscds.fasta"  # Large file with all nucleotide sequences
msa_input_dir = "batstring_paired"  # Directory with per-gene protein alignments
output_dir = "batstring_nucs"  # Directory to store codon alignments

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Function to parse IDs and handle repeated names
def extract_gene_id(header):
    """Extract the first gene ID from a header with duplicate IDs."""
    return header.split()[0]  # Take the first part of the header

# Load nucleotide sequences into a dictionary, using only the first part of the ID
print("Loading nucleotide sequences from mergedprotscds.fasta...")
nucleotide_dict = {}
for record in SeqIO.parse(nucleotide_fasta, "fasta"):
    gene_id = extract_gene_id(record.id)
    nucleotide_dict[gene_id] = record
print(f"Loaded {len(nucleotide_dict)} nucleotide sequences.")

# Process each MSA input file
for msa_file in os.listdir(msa_input_dir):
    if msa_file.endswith(".fasta") or msa_file.endswith(".fa"):
        msa_path = os.path.join(msa_input_dir, msa_file)
        gene_name = os.path.splitext(msa_file)[0]
        output_nucleotide_file = os.path.join(output_dir, f"{gene_name}_nucleotide.fasta")
        output_codon_alignment_file = os.path.join(output_dir, f"{gene_name}_codon_alignment.fasta")

        # Extract protein IDs from the MSA file
        protein_ids = []
        with open(msa_path, "r") as msa_handle:
            for record in SeqIO.parse(msa_handle, "fasta"):
                protein_id = extract_gene_id(record.id)  # Extract the first part of the header
                protein_ids.append(protein_id)
        
        # Match nucleotide sequences to the protein IDs
        matching_nucleotides = []
        for pid in protein_ids:
            if pid in nucleotide_dict:
                matching_nucleotides.append(nucleotide_dict[pid])
            else:
                print(f"Warning: Protein ID {pid} not found in nucleotide file.")
        
        # Write matching nucleotide sequences to a new file
        if matching_nucleotides:
            with open(output_nucleotide_file, "w") as output_handle:
                SeqIO.write(matching_nucleotides, output_handle, "fasta")
            print(f"Extracted nucleotide sequences for {gene_name}.")

            # Run pal2nal
            print(f"Running pal2nal for {gene_name}...")
            pal2nal_command = f"perl pal2nal.pl {msa_path} {output_nucleotide_file} -output fasta -verbose -nogap > {output_codon_alignment_file}"
            os.system(pal2nal_command)
            print(f"Codon alignment saved to {output_codon_alignment_file}.")
        else:
            print(f"No matching nucleotide sequences found for {gene_name}. Skipping...")
# Out:
# Loading nucleotide sequences from mergedprotscds.fasta...
# Loaded 862310 nucleotide sequences.
# Extracted nucleotide sequences for 59463.ENSMLUP00000000083_bat_only.
# Running pal2nal for 59463.ENSMLUP00000000083_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000000083_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000001427_bat_only.
# Running pal2nal for 59463.ENSMLUP00000001427_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000001427_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000001789_bat_only.
# Running pal2nal for 59463.ENSMLUP00000001789_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000001789_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000002616_bat_only.
# Running pal2nal for 59463.ENSMLUP00000002616_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000002616_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000002847_bat_only.
# Running pal2nal for 59463.ENSMLUP00000002847_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000002847_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000003315_bat_only.
# Running pal2nal for 59463.ENSMLUP00000003315_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000003315_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000003322_bat_only.
# Running pal2nal for 59463.ENSMLUP00000003322_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000003322_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000004009_bat_only.
# Running pal2nal for 59463.ENSMLUP00000004009_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000004009_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000004202_bat_only.
# Running pal2nal for 59463.ENSMLUP00000004202_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000004202_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000005054_bat_only.
# Running pal2nal for 59463.ENSMLUP00000005054_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000005054_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000005277_bat_only.
# Running pal2nal for 59463.ENSMLUP00000005277_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000005277_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000005366_bat_only.
# Running pal2nal for 59463.ENSMLUP00000005366_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000005366_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000005595_bat_only.
# Running pal2nal for 59463.ENSMLUP00000005595_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000005595_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000008027_bat_only.
# Running pal2nal for 59463.ENSMLUP00000008027_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000008027_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000009180_bat_only.
# Running pal2nal for 59463.ENSMLUP00000009180_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000009180_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000009404_bat_only.
# Running pal2nal for 59463.ENSMLUP00000009404_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000009404_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000010380_bat_only.
# Running pal2nal for 59463.ENSMLUP00000010380_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000010380_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000011160_bat_only.
# Running pal2nal for 59463.ENSMLUP00000011160_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000011160_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000011196_bat_only.
# Running pal2nal for 59463.ENSMLUP00000011196_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000011196_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000011227_bat_only.
# Running pal2nal for 59463.ENSMLUP00000011227_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000011227_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000011717_bat_only.
# Running pal2nal for 59463.ENSMLUP00000011717_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000011717_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000012090_bat_only.
# Running pal2nal for 59463.ENSMLUP00000012090_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000012090_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000013453_bat_only.
# Running pal2nal for 59463.ENSMLUP00000013453_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000013453_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000013787_bat_only.
# Running pal2nal for 59463.ENSMLUP00000013787_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000013787_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000014213_bat_only.
# Running pal2nal for 59463.ENSMLUP00000014213_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000014213_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000016071_bat_only.
# Running pal2nal for 59463.ENSMLUP00000016071_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000016071_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000016363_bat_only.
# Running pal2nal for 59463.ENSMLUP00000016363_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000016363_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000016529_bat_only.
# Running pal2nal for 59463.ENSMLUP00000016529_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000016529_bat_only_codon_alignment.fasta.
# Extracted nucleotide sequences for 59463.ENSMLUP00000022559_bat_only.
# Running pal2nal for 59463.ENSMLUP00000022559_bat_only...
# Codon alignment saved to batstring_nucs\59463.ENSMLUP00000022559_bat_only_codon_alignment.fasta.

# %% [markdown]
# Then MASCE then PAL2NAL

# %% [markdown]
# TREES GENERATION

# %%
from ete3 import Tree
from Bio import SeqIO
import os

# Paths
full_tree_file = "bat_tags_noen.nwk"  # Path to the full tree file
pal2nal_dir = "batstring_pal2nal"  # Directory with cleaned codon-aligned files
output_tree_dir = "batstring_trees"  # Directory to store pruned trees

# Species tag to full name mapping
tag_to_species = {
    "rf": "Rhinolophus_ferrumequinum",
    "dr": "Desmodus_rotundus",
    "ra": "Rousettus_aegyptiacus",
    "pv": "Pteropus_vampyrus",
    "pg": "Pteropus_giganteus",
    "pa": "Pteropus_alecto",
    "pk": "Pipistrellus_kuhlii",
    "ph": "Phyllostomus_hastatus",
    "pd": "Phyllostomus_discolor",
    "mm": "Myotis_myotis",
    "ml": "Myotis_lucifugus",
    "mb": "Myotis_brandtii",
    "mo": "Molossus_molossus",
    "md": "Myotis_daubentonii",
    "sb": "Saccopteryx_bilineata",
    "aj": "Artibeus_jamaicensis",
    "pn": "Pipistrellus_nathusii",
    "en": "Eptesicus_nilssonii",
}

# Create output directory if it doesn't exist
os.makedirs(output_tree_dir, exist_ok=True)

# Load the full tree
full_tree = Tree(full_tree_file, format=1)

# Process each alignment file
for alignment_file in os.listdir(pal2nal_dir):
    if alignment_file.endswith(".fasta"):
        alignment_path = os.path.join(pal2nal_dir, alignment_file)

        # Check if the file is empty
        if os.stat(alignment_path).st_size == 0:
            print(f"Skipping empty file: {alignment_file}")
            continue

        print(f"\nProcessing: {alignment_file}")

        # Extract sequence names from the alignment
        sequence_names = {}
        for record in SeqIO.parse(alignment_path, "fasta"):
            tag = record.id[:2]  # Extract the first two letters of the record ID
            if tag in tag_to_species:
                species_name = tag_to_species[tag]
                sequence_names[species_name] = record.id
            else:
                print(f"Warning: Unrecognized tag '{tag}' in {record.id}")

        # Debugging: Print extracted sequence names
        print(f"Extracted sequence names for {alignment_file}:")
        for species, seq_id in sequence_names.items():
            print(f"  {species}: {seq_id}")

        # Copy the full tree for modification
        unique_tree = full_tree.copy()

        # Rename leaves to match sequence names and remove unmatched leaves
        unmatched_leaves = []
        for leaf in unique_tree.get_leaves():
            if leaf.name in sequence_names:
                leaf.name = sequence_names[leaf.name]  # Rename leaf to match sequence ID
            else:
                unmatched_leaves.append(leaf.name)

        # Debugging: Print unmatched leaves
        if unmatched_leaves:
            print(f"Unmatched leaves for {alignment_file}: {unmatched_leaves}")

        # Remove unmatched leaves
        for leaf_name in unmatched_leaves:
            leaf = unique_tree.search_nodes(name=leaf_name)[0]
            leaf.detach()

        # Save the unique tree
        output_tree_path = os.path.join(output_tree_dir, f"{alignment_file}_pruned.nwk")
        unique_tree.write(outfile=output_tree_path, format=1)
        print(f"Unique tree saved to: {output_tree_path}")
# Out:
# Processing: 59463.ENSMLUP00000000083_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000000083_bat_only_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032946134.1
#   Pipistrellus_nathusii: pnCAK6438137.1
#   Pipistrellus_kuhlii: pkXP_036306523.1
#   Molossus_molossus: moXP_036123910.1
#   Myotis_daubentonii: mdXP_059526062.1
#   Myotis_myotis: mmXP_036195761.1
#   Saccopteryx_bilineata: sbXP_066093091.1
#   Desmodus_rotundus: drXP_053766493.1
#   Artibeus_jamaicensis: ajXP_036983857.1
#   Phyllostomus_hastatus: phXP_045691911.1
#   Phyllostomus_discolor: pdXP_028375016.1
#   Rousettus_aegyptiacus: raXP_015999162.1
#   Pteropus_giganteus: pgXP_039715138.1
#   Pteropus_alecto: paXP_006912343.1
#   Pteropus_vampyrus: pvXP_011366803.1
#   Myotis_lucifugus: mlXP_023612723.1
#   Myotis_brandtii: mbXP_005875843.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000000083_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000001427_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000001427_bat_only_nucleotide_codon_aligned.fasta:
#   Desmodus_rotundus: drXP_024433875.1
#   Rhinolophus_ferrumequinum: rfXP_032943217.1
#   Pteropus_vampyrus: pvXP_023381416.1
#   Pteropus_giganteus: pgXP_039706701.1
#   Pteropus_alecto: paXP_015455545.1
#   Pipistrellus_nathusii: pnCAK6441771.1
#   Pipistrellus_kuhlii: pkXP_036302719.1
#   Myotis_myotis: mmXP_036208258.1
#   Myotis_lucifugus: mlXP_006084811.1
#   Myotis_brandtii: mbXP_005873252.1
#   Myotis_daubentonii: mdXP_059543434.1
#   Molossus_molossus: moXP_036099218.1
#   Rousettus_aegyptiacus: raXP_015990781.2
#   Saccopteryx_bilineata: sbXP_066097555.1
#   Artibeus_jamaicensis: ajXP_036993059.2
#   Phyllostomus_hastatus: phXP_045707315.1
#   Phyllostomus_discolor: pdXP_028360749.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000001427_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000001789_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000001789_bat_only_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032971332.1
#   Saccopteryx_bilineata: sbXP_066126286.1
#   Pipistrellus_kuhlii: pkXP_036302572.1
#   Pipistrellus_nathusii: pnCAK6440718.1
#   Myotis_myotis: mmXP_036207606.1
#   Myotis_lucifugus: mlXP_006094076.1
#   Myotis_daubentonii: mdXP_059546891.1
#   Myotis_brandtii: mbXP_005859738.1
#   Molossus_molossus: moXP_036112964.1
#   Desmodus_rotundus: drXP_024410096.1
#   Artibeus_jamaicensis: ajXP_036991776.2
#   Phyllostomus_hastatus: phXP_045715589.1
#   Phyllostomus_discolor: pdXP_035881363.1
#   Rousettus_aegyptiacus: raXP_016004729.2
#   Pteropus_giganteus: pgXP_039710232.1
#   Pteropus_alecto: paXP_006924536.1
#   Pteropus_vampyrus: pvXP_011356324.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000001789_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000002616_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000002616_bat_only_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032990906.1
#   Desmodus_rotundus: drXP_024425024.1
#   Artibeus_jamaicensis: ajXP_037018247.2
#   Phyllostomus_hastatus: phXP_045687553.1
#   Phyllostomus_discolor: pdXP_028375516.1
#   Rousettus_aegyptiacus: raXP_016014391.1
#   Pteropus_vampyrus: pvXP_023385989.1
#   Pteropus_giganteus: pgXP_039731941.1
#   Pteropus_alecto: paXP_024898165.1
#   Myotis_myotis: mmXP_036169772.1
#   Myotis_daubentonii: mdXP_059553879.1
#   Myotis_lucifugus: mlXP_014311180.1
#   Myotis_brandtii: mbXP_005871463.1
#   Pipistrellus_nathusii: pnCAK6445899.1
#   Pipistrellus_kuhlii: pkXP_045432385.1
#   Molossus_molossus: moXP_036096354.1
#   Saccopteryx_bilineata: sbXP_066137369.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000002616_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000002847_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000002847_bat_only_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032969289.1
#   Rousettus_aegyptiacus: raXP_016009829.1
#   Pteropus_vampyrus: pvXP_011361195.1
#   Pteropus_giganteus: pgXP_039713374.1
#   Pteropus_alecto: paXP_006909323.1
#   Saccopteryx_bilineata: sbXP_066121018.1
#   Desmodus_rotundus: drXP_024421388.1
#   Phyllostomus_hastatus: phXP_045703068.1
#   Phyllostomus_discolor: pdXP_035882395.1
#   Artibeus_jamaicensis: ajXP_037008806.2
#   Myotis_myotis: mmXP_036207802.1
#   Myotis_daubentonii: mdXP_059544627.1
#   Myotis_lucifugus: mlXP_014314819.1
#   Myotis_brandtii: mbXP_005878486.1
#   Pipistrellus_nathusii: pnCAK6441408.1
#   Pipistrellus_kuhlii: pkXP_036302573.1
#   Molossus_molossus: moXP_036112869.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000002847_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000003315_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000003315_bat_only_nucleotide_codon_aligned.fasta:
#   Artibeus_jamaicensis: ajXP_037020870.2
#   Myotis_lucifugus: mlXP_006102661.1
#   Myotis_brandtii: mbXP_005878849.1
#   Rhinolophus_ferrumequinum: rfXP_032946413.1
#   Desmodus_rotundus: drXP_024420605.2
#   Phyllostomus_hastatus: phXP_045680450.1
#   Phyllostomus_discolor: pdXP_028390175.1
#   Rousettus_aegyptiacus: raXP_016010199.2
#   Pteropus_vampyrus: pvXP_011357230.1
#   Pteropus_giganteus: pgXP_039703228.1
#   Pteropus_alecto: paXP_006922427.2
#   Molossus_molossus: moXP_036125294.1
#   Pipistrellus_nathusii: pnCAK6437681.1
#   Pipistrellus_kuhlii: pkXP_036308020.1
#   Myotis_daubentonii: mdXP_059524654.1
#   Myotis_myotis: mmXP_036197834.1
#   Saccopteryx_bilineata: sbXP_066120310.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000003315_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000003322_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000003322_bat_only_nucleotide_codon_aligned.fasta:
#   Rousettus_aegyptiacus: raXP_015997976.2
#   Pteropus_giganteus: pgXP_039727061.1
#   Pteropus_alecto: paXP_006921000.1
#   Rhinolophus_ferrumequinum: rfXP_032986834.1
#   Saccopteryx_bilineata: sbXP_066095214.1
#   Desmodus_rotundus: drXP_045047578.2
#   Artibeus_jamaicensis: ajXP_053524495.1
#   Phyllostomus_hastatus: phXP_045710189.1
#   Phyllostomus_discolor: pdXP_028368820.1
#   Myotis_myotis: mmXP_036191760.1
#   Myotis_lucifugus: mlXP_006088216.1
#   Myotis_daubentonii: mdXP_059517512.1
#   Myotis_brandtii: mbXP_005874619.1
#   Pipistrellus_kuhlii: pkXP_036295060.1
#   Pipistrellus_nathusii: pnCAK6436079.1
#   Molossus_molossus: moXP_036121405.1
#   Pteropus_vampyrus: pvXP_011357616.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000003322_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000004009_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000004009_bat_only_nucleotide_codon_aligned.fasta:
#   Rousettus_aegyptiacus: raXP_015999463.2
#   Rhinolophus_ferrumequinum: rfXP_032960936.1
#   Pteropus_vampyrus: pvXP_011362316.1
#   Pteropus_alecto: paXP_006916440.1
#   Pteropus_giganteus: pgXP_039738780.1
#   Desmodus_rotundus: drXP_024418601.1
#   Phyllostomus_hastatus: phXP_045677680.1
#   Phyllostomus_discolor: pdXP_028382052.2
#   Saccopteryx_bilineata: sbXP_066093548.1
#   Molossus_molossus: moXP_036106138.1
#   Myotis_myotis: mmXP_036152966.1
#   Myotis_daubentonii: mdXP_059537099.1
#   Myotis_lucifugus: mlXP_023612896.1
#   Myotis_brandtii: mbXP_014386881.1
#   Artibeus_jamaicensis: ajXP_036984798.2
#   Pipistrellus_nathusii: pnCAK6442564.1
#   Pipistrellus_kuhlii: pkXP_045443435.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000004009_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000004202_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000004202_bat_only_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032946676.1
#   Rousettus_aegyptiacus: raXP_016006474.2
#   Pteropus_giganteus: pgXP_039729753.1
#   Pteropus_alecto: paXP_006924730.1
#   Pteropus_vampyrus: pvXP_011381398.1
#   Desmodus_rotundus: drXP_024428890.2
#   Phyllostomus_hastatus: phXP_045692366.1
#   Phyllostomus_discolor: pdXP_028376247.1
#   Artibeus_jamaicensis: ajXP_036985630.2
#   Saccopteryx_bilineata: sbXP_066119769.1
#   Myotis_myotis: mmXP_036197705.1
#   Myotis_lucifugus: mlXP_006095025.1
#   Myotis_daubentonii: mdXP_059526981.1
#   Myotis_brandtii: mbXP_005861908.1
#   Pipistrellus_nathusii: pnCAK6438415.1
#   Pipistrellus_kuhlii: pkXP_036263632.1
#   Molossus_molossus: moXP_036124041.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000004202_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000005054_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000005054_bat_only_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032956699.1
#   Rousettus_aegyptiacus: raXP_016015693.1
#   Pteropus_giganteus: pgXP_039725816.1
#   Pteropus_alecto: paXP_006926112.1
#   Desmodus_rotundus: drXP_053769596.1
#   Artibeus_jamaicensis: ajXP_037014889.2
#   Phyllostomus_hastatus: phXP_045699260.1
#   Phyllostomus_discolor: pdXP_028364317.1
#   Molossus_molossus: moXP_036104500.1
#   Pipistrellus_nathusii: pnCAK6446717.1
#   Pipistrellus_kuhlii: pkXP_036271341.1
#   Myotis_myotis: mmXP_036172070.1
#   Myotis_lucifugus: mlXP_006098082.1
#   Myotis_daubentonii: mdXP_059556772.1
#   Saccopteryx_bilineata: sbXP_066103763.1
#   Myotis_brandtii: mbXP_005883885.2
#   Pteropus_vampyrus: pvXP_023386725.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000005054_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Skipping empty file: 59463.ENSMLUP00000005277_bat_only_nucleotide_codon_aligned.fasta
#
# Processing: 59463.ENSMLUP00000005366_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000005366_bat_only_nucleotide_codon_aligned.fasta:
#   Phyllostomus_discolor: pdXP_035867530.1
#   Rhinolophus_ferrumequinum: rfXP_032960851.1
#   Pteropus_vampyrus: pvXP_011371577.1
#   Molossus_molossus: moXP_036105838.1
#   Artibeus_jamaicensis: ajXP_053515842.1
#   Rousettus_aegyptiacus: raXP_036084611.1
#   Pteropus_giganteus: pgXP_039702365.1
#   Pteropus_alecto: paXP_006916392.1
#   Pipistrellus_nathusii: pnCAK6442623.1
#   Pipistrellus_kuhlii: pkXP_036314135.1
#   Myotis_daubentonii: mdXP_059541456.1
#   Myotis_myotis: mmXP_036154392.1
#   Myotis_lucifugus: mlXP_023607616.1
#   Myotis_brandtii: mbXP_014393357.1
#   Saccopteryx_bilineata: sbXP_066091206.1
#   Desmodus_rotundus: drXP_053772323.1
#   Phyllostomus_hastatus: phXP_045677464.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000005366_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000005595_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000005595_bat_only_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032946676.1
#   Rousettus_aegyptiacus: raXP_016006474.2
#   Pteropus_giganteus: pgXP_039729753.1
#   Pteropus_alecto: paXP_006924730.1
#   Pteropus_vampyrus: pvXP_011381398.1
#   Desmodus_rotundus: drXP_024428890.2
#   Phyllostomus_hastatus: phXP_045692366.1
#   Phyllostomus_discolor: pdXP_028376247.1
#   Artibeus_jamaicensis: ajXP_036985630.2
#   Saccopteryx_bilineata: sbXP_066119769.1
#   Myotis_myotis: mmXP_036197705.1
#   Myotis_lucifugus: mlXP_006095025.1
#   Myotis_daubentonii: mdXP_059526981.1
#   Myotis_brandtii: mbXP_005861908.1
#   Pipistrellus_nathusii: pnCAK6438415.1
#   Pipistrellus_kuhlii: pkXP_036263632.1
#   Molossus_molossus: moXP_036124041.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000005595_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000008027_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000008027_bat_only_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032943586.1
#   Desmodus_rotundus: drXP_024436450.2
#   Rousettus_aegyptiacus: raXP_016003904.1
#   Phyllostomus_hastatus: phXP_045705558.1
#   Phyllostomus_discolor: pdXP_028380653.1
#   Artibeus_jamaicensis: ajXP_037021015.2
#   Molossus_molossus: moXP_036101281.1
#   Saccopteryx_bilineata: sbXP_066103492.1
#   Pteropus_vampyrus: pvXP_011359430.1
#   Pteropus_alecto: paXP_006919993.1
#   Pteropus_giganteus: pgXP_039698376.1
#   Myotis_brandtii: mbXP_005865805.2
#   Myotis_myotis: mmXP_036179611.1
#   Myotis_daubentonii: mdXP_059563204.1
#   Pipistrellus_nathusii: pnCAK6447973.1
#   Pipistrellus_kuhlii: pkXP_036273992.1
#   Myotis_lucifugus: mlXP_006109748.2
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000008027_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000009180_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000009180_bat_only_nucleotide_codon_aligned.fasta:
#   Myotis_lucifugus: mlXP_023600738.1
#   Pteropus_vampyrus: pvXP_023384443.1
#   Saccopteryx_bilineata: sbXP_066107369.1
#   Rhinolophus_ferrumequinum: rfXP_032977584.1
#   Rousettus_aegyptiacus: raXP_015978729.1
#   Pteropus_alecto: paXP_006908094.1
#   Pteropus_giganteus: pgXP_039722978.1
#   Molossus_molossus: moXP_036113887.1
#   Desmodus_rotundus: drXP_024414685.1
#   Artibeus_jamaicensis: ajXP_053529084.1
#   Phyllostomus_hastatus: phXP_045681526.1
#   Phyllostomus_discolor: pdXP_028371519.1
#   Myotis_myotis: mmXP_036182083.1
#   Myotis_brandtii: mbXP_005864486.1
#   Myotis_daubentonii: mdXP_059565645.1
#   Pipistrellus_kuhlii: pkXP_036284360.1
#   Pipistrellus_nathusii: pnCAK6449506.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000009180_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000009404_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000009404_bat_only_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032948995.1
#   Myotis_myotis: mmXP_036199724.1
#   Phyllostomus_hastatus: phXP_045697522.1
#   Artibeus_jamaicensis: ajXP_053523998.1
#   Phyllostomus_discolor: pdXP_028386799.1
#   Saccopteryx_bilineata: sbXP_066111249.1
#   Molossus_molossus: moXP_036129501.1
#   Myotis_daubentonii: mdXP_059531184.1
#   Desmodus_rotundus: drXP_024427405.1
#   Rousettus_aegyptiacus: raXP_015996560.2
#   Pteropus_vampyrus: pvXP_011371263.1
#   Pteropus_giganteus: pgXP_039737823.1
#   Pteropus_alecto: paXP_006922897.1
#   Pipistrellus_nathusii: pnCAK6439716.1
#   Pipistrellus_kuhlii: pkXP_036298830.1
#   Myotis_lucifugus: mlXP_006094908.1
#   Myotis_brandtii: mbXP_005885346.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000009404_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Skipping empty file: 59463.ENSMLUP00000010380_bat_only_nucleotide_codon_aligned.fasta
#
# Processing: 59463.ENSMLUP00000011160_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000011160_bat_only_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032990303.1
#   Rousettus_aegyptiacus: raXP_015987888.2
#   Pteropus_vampyrus: pvXP_011365053.1
#   Pteropus_giganteus: pgXP_039723858.1
#   Pteropus_alecto: paXP_006904386.1
#   Myotis_brandtii: mbXP_005873961.2
#   Myotis_myotis: mmXP_036167606.1
#   Myotis_daubentonii: mdXP_059552122.1
#   Myotis_lucifugus: mlXP_006100443.1
#   Pipistrellus_kuhlii: pkXP_036305808.1
#   Pipistrellus_nathusii: pnCAK6445298.1
#   Molossus_molossus: moXP_036095710.1
#   Saccopteryx_bilineata: sbXP_066125039.1
#   Desmodus_rotundus: drXP_024416550.1
#   Artibeus_jamaicensis: ajXP_036998032.2
#   Phyllostomus_hastatus: phXP_045709182.1
#   Phyllostomus_discolor: pdXP_028376370.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000011160_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000011196_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000011196_bat_only_nucleotide_codon_aligned.fasta:
#   Pipistrellus_kuhlii: pkXP_036272319.2
#   Rhinolophus_ferrumequinum: rfXP_032984803.1
#   Pipistrellus_nathusii: pnCAK6437196.1
#   Myotis_daubentonii: mdXP_059522145.1
#   Myotis_myotis: mmXP_036201853.1
#   Desmodus_rotundus: drXP_024425231.1
#   Phyllostomus_hastatus: phXP_045701093.1
#   Artibeus_jamaicensis: ajXP_037003923.1
#   Phyllostomus_discolor: pdXP_028385790.1
#   Molossus_molossus: moXP_036130990.1
#   Pteropus_giganteus: pgXP_039722132.1
#   Pteropus_alecto: paXP_024902552.1
#   Saccopteryx_bilineata: sbXP_066127896.1
#   Myotis_brandtii: mbXP_005863442.1
#   Rousettus_aegyptiacus: raXP_036088371.1
#   Pteropus_vampyrus: pvXP_023391126.1
#   Myotis_lucifugus: mlXP_023604919.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000011196_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000011227_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000011227_bat_only_nucleotide_codon_aligned.fasta:
#   Myotis_brandtii: mbXP_014392858.1
#   Myotis_myotis: mmXP_036201301.1
#   Rhinolophus_ferrumequinum: rfXP_032983309.1
#   Saccopteryx_bilineata: sbXP_066127918.1
#   Rousettus_aegyptiacus: raXP_036088415.1
#   Pteropus_vampyrus: pvXP_011366253.1
#   Pteropus_alecto: paXP_015444810.1
#   Pteropus_giganteus: pgXP_039722139.1
#   Molossus_molossus: moXP_036131859.1
#   Pipistrellus_nathusii: pnCAK6437199.1
#   Pipistrellus_kuhlii: pkXP_036272368.1
#   Myotis_daubentonii: mdXP_059522134.1
#   Myotis_lucifugus: mlXP_014304701.2
#   Desmodus_rotundus: drXP_024425273.2
#   Phyllostomus_hastatus: phXP_045701187.1
#   Phyllostomus_discolor: pdXP_028385851.1
#   Artibeus_jamaicensis: ajXP_037003912.2
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000011227_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000011717_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000011717_bat_only_nucleotide_codon_aligned.fasta:
#   Pipistrellus_nathusii: pnCAK6438461.1
#   Rhinolophus_ferrumequinum: rfXP_032945859.1
#   Pteropus_vampyrus: pvXP_011379562.1
#   Phyllostomus_hastatus: phXP_045693148.1
#   Desmodus_rotundus: drXP_024409255.1
#   Molossus_molossus: moXP_036124284.1
#   Rousettus_aegyptiacus: raXP_016006487.2
#   Pteropus_giganteus: pgXP_039729736.1
#   Pteropus_alecto: paXP_006924699.1
#   Phyllostomus_discolor: pdXP_028375175.2
#   Saccopteryx_bilineata: sbXP_066119747.1
#   Pipistrellus_kuhlii: pkXP_036263611.1
#   Myotis_myotis: mmXP_036194923.1
#   Myotis_daubentonii: mdXP_059526989.1
#   Myotis_lucifugus: mlXP_006095031.1
#   Myotis_brandtii: mbXP_005862025.1
#   Artibeus_jamaicensis: ajXP_036985597.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000011717_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000012090_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000012090_bat_only_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032955476.1
#   Artibeus_jamaicensis: ajXP_037016765.2
#   Myotis_brandtii: mbXP_014387840.1
#   Saccopteryx_bilineata: sbXP_066094798.1
#   Molossus_molossus: moXP_036133433.1
#   Desmodus_rotundus: drXP_045040527.2
#   Rousettus_aegyptiacus: raXP_016006050.1
#   Pteropus_vampyrus: pvXP_011365554.1
#   Pteropus_giganteus: pgXP_039739437.1
#   Myotis_myotis: mmXP_036211051.1
#   Myotis_daubentonii: mdXP_059533887.1
#   Phyllostomus_hastatus: phXP_045673108.1
#   Phyllostomus_discolor: pdXP_035871977.1
#   Pipistrellus_nathusii: pnCAK6442310.1
#   Myotis_lucifugus: mlXP_023604648.1
#   Pipistrellus_kuhlii: pkXP_036296085.1
#   Pteropus_alecto: paXP_024900574.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000012090_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000013453_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000013453_bat_only_nucleotide_codon_aligned.fasta:
#   Phyllostomus_hastatus: phXP_045680629.1
#   Myotis_daubentonii: mdXP_059524875.1
#   Rhinolophus_ferrumequinum: rfXP_032947164.1
#   Myotis_myotis: mmXP_036197234.1
#   Myotis_lucifugus: mlXP_006105147.1
#   Myotis_brandtii: mbXP_014405388.1
#   Pipistrellus_nathusii: pnCAK6437759.1
#   Pipistrellus_kuhlii: pkXP_036307678.1
#   Saccopteryx_bilineata: sbXP_066119007.1
#   Artibeus_jamaicensis: ajXP_036985111.2
#   Phyllostomus_discolor: pdXP_035889055.1
#   Molossus_molossus: moXP_036124931.1
#   Rousettus_aegyptiacus: raXP_015997557.2
#   Pteropus_vampyrus: pvXP_023386162.1
#   Pteropus_giganteus: pgXP_039730598.1
#   Pteropus_alecto: paXP_006922338.1
#   Desmodus_rotundus: drXP_045055206.2
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000013453_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000013787_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000013787_bat_only_nucleotide_codon_aligned.fasta:
#   Saccopteryx_bilineata: sbXP_066129585.1
#   Pipistrellus_kuhlii: pkXP_036280301.1
#   Rhinolophus_ferrumequinum: rfXP_032952375.1
#   Rousettus_aegyptiacus: raXP_036080377.1
#   Pteropus_vampyrus: pvXP_023388557.1
#   Pteropus_giganteus: pgXP_039734888.1
#   Molossus_molossus: moXP_036097890.1
#   Desmodus_rotundus: drXP_024432590.2
#   Artibeus_jamaicensis: ajXP_036993816.1
#   Phyllostomus_hastatus: phXP_045680737.1
#   Phyllostomus_discolor: pdXP_028383086.1
#   Myotis_myotis: mmXP_036168455.1
#   Myotis_daubentonii: mdXP_059555375.1
#   Pipistrellus_nathusii: pnCAK6446407.1
#   Myotis_lucifugus: mlXP_014305940.1
#   Myotis_brandtii: mbXP_014386464.1
#   Pteropus_alecto: paXP_024905335.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000013787_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000014213_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000014213_bat_only_nucleotide_codon_aligned.fasta:
#   Pteropus_vampyrus: pvXP_011379860.1
#   Phyllostomus_hastatus: phXP_045707297.1
#   Pipistrellus_kuhlii: pkXP_036300663.1
#   Myotis_daubentonii: mdXP_059543353.1
#   Myotis_lucifugus: mlXP_006084840.2
#   Myotis_brandtii: mbXP_005880821.2
#   Rhinolophus_ferrumequinum: rfXP_032945966.1
#   Myotis_myotis: mmXP_036203510.1
#   Pteropus_alecto: paXP_024898058.1
#   Desmodus_rotundus: drXP_024420519.1
#   Phyllostomus_discolor: pdXP_028360552.2
#   Rousettus_aegyptiacus: raXP_015991808.2
#   Pteropus_giganteus: pgXP_039706604.1
#   Molossus_molossus: moXP_036098758.1
#   Saccopteryx_bilineata: sbXP_066097288.1
#   Artibeus_jamaicensis: ajXP_036987670.1
#   Pipistrellus_nathusii: pnCAK6441801.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000014213_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: 59463.ENSMLUP00000016071_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000016071_bat_only_nucleotide_codon_aligned.fasta:
#   Phyllostomus_discolor: pdXP_028369249.1
#   Rousettus_aegyptiacus: raXP_016004931.2
#   Pteropus_vampyrus: pvXP_023388381.1
#   Pteropus_giganteus: pgXP_039698121.1
#   Pteropus_alecto: paXP_015446900.1
#   Rhinolophus_ferrumequinum: rfXP_032971383.1
#   Desmodus_rotundus: drXP_024410613.2
#   Artibeus_jamaicensis: ajXP_037021567.2
#   Phyllostomus_hastatus: phXP_045715842.1
#   Saccopteryx_bilineata: sbXP_066126507.1
#   Molossus_molossus: moXP_036111589.1
#   Pipistrellus_nathusii: pnCAK6440610.1
#   Pipistrellus_kuhlii: pkXP_036316803.1
#   Myotis_myotis: mmXP_036205755.1
#   Myotis_daubentonii: mdXP_059547208.1
#   Myotis_lucifugus: mlXP_006104586.1
#   Myotis_brandtii: mbXP_005873547.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000016071_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Skipping empty file: 59463.ENSMLUP00000016363_bat_only_nucleotide_codon_aligned.fasta
#
# Processing: 59463.ENSMLUP00000016529_bat_only_nucleotide_codon_aligned.fasta
# Extracted sequence names for 59463.ENSMLUP00000016529_bat_only_nucleotide_codon_aligned.fasta:
#   Saccopteryx_bilineata: sbXP_066111434.1
#   Desmodus_rotundus: drXP_045055206.2
#   Myotis_myotis: mmXP_036197236.1
#   Rhinolophus_ferrumequinum: rfXP_032947163.1
#   Rousettus_aegyptiacus: raXP_015997557.2
#   Pteropus_vampyrus: pvXP_023386162.1
#   Pteropus_giganteus: pgXP_039730598.1
#   Pteropus_alecto: paXP_006922338.1
#   Pipistrellus_nathusii: pnCAK6437761.1
#   Pipistrellus_kuhlii: pkXP_036307681.1
#   Myotis_brandtii: mbXP_014397415.1
#   Myotis_daubentonii: mdXP_059524892.1
#   Myotis_lucifugus: mlXP_014302774.1
#   Molossus_molossus: moXP_036125124.1
#   Artibeus_jamaicensis: ajXP_036985111.2
#   Phyllostomus_discolor: pdXP_035889055.1
#   Phyllostomus_hastatus: phXP_045680628.1
# Unique tree saved to: batstring_trees\59463.ENSMLUP00000016529_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Skipping empty file: 59463.ENSMLUP00000022559_bat_only_nucleotide_codon_aligned.fasta

# %%
#!/usr/bin/env python3

import os
import re

SOURCE_DIR = 'batstring_trees'
DEST_DIR = 'batstring_trees_labeled'

os.makedirs(DEST_DIR, exist_ok=True)

# Prefixes that should be labeled as {Foreground}
foreground_prefixes = ['mm', 'ml', 'md', 'mb', 'dr', 'rf']

# Regex: capture (1) node/tip name, (2) colon+branch_length
pattern = re.compile(r'([^\(\),:]+)(:[0-9\.eE\-\+]+)')

def replacer(match):
    """Decide {Foreground} vs. {Background}."""
    taxon_name = match.group(1)
    branch_length = match.group(2)
    if any(taxon_name.startswith(pref) for pref in foreground_prefixes):
        return f"{taxon_name}{{Foreground}}{branch_length}"
    else:
        return f"{taxon_name}{{Background}}{branch_length}"

for filename in os.listdir(SOURCE_DIR):
    if filename.endswith('.nwk'):
        source_file = os.path.join(SOURCE_DIR, filename)
        dest_file = os.path.join(DEST_DIR, filename)

        with open(source_file, 'r') as infile:
            data = infile.read()

        # --- FORCE ONE LINE ---
        # Remove all linebreaks:
        data = data.replace('\n', '').replace('\r', '')
        # (Optional) remove extra spaces if you like:
        # data = ' '.join(data.split())

        # Perform the labeling
        data_labeled = pattern.sub(replacer, data)

        # Write out WITHOUT adding an extra newline at the end
        with open(dest_file, 'w') as outfile:
            outfile.write(data_labeled)

        print(f"Processed {filename} -> {dest_file}")
# Out:
# Processed 59463.ENSMLUP00000000083_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000000083_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000001427_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000001427_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000001789_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000001789_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000002616_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000002616_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000002847_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000002847_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000003315_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000003315_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000003322_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000003322_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000004009_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000004009_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000004202_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000004202_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000005054_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000005054_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000005366_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000005366_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000005595_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000005595_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000008027_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000008027_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000009180_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000009180_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000009404_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000009404_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000011160_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000011160_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000011196_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000011196_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000011227_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000011227_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000011717_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000011717_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000012090_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000012090_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000013453_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000013453_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000013787_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000013787_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000014213_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000014213_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000016071_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000016071_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk
# Processed 59463.ENSMLUP00000016529_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk -> batstring_trees_labeled\59463.ENSMLUP00000016529_bat_only_nucleotide_codon_aligned.fasta_pruned.nwk

# %% [markdown]
# DN DS

# %%
import os
import re

# Define the directory containing your .log files
log_dir = 'batstring_busted'  # Update this if your directory name is different

# Output file to store the protein names
output_file = 'batstring_bustede1_prots_nofdr.txt'

# Open the output file in write mode
with open(output_file, 'w') as out_f:

    # Iterate over all .log files in the directory
    for filename in os.listdir(log_dir):
        if filename.endswith('.log'):
            filepath = os.path.join(log_dir, filename)
            # Extract the protein name from the filename based on the rules
            # Split the filename by '_'
            parts = filename.split('_')
            if parts[0].startswith('NP') or parts[0].startswith('XP'):
                # If the protein name starts with 'NP' or 'XP', join the first two parts
                protein_name = '_'.join(parts[:2])
            else:
                # Otherwise, the protein name is the first part
                protein_name = parts[0]

            # Open and read the log file
            with open(filepath, 'r') as log_f:
                lines = log_f.readlines()
                for line in lines:
                    if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                        # Extract the p-value from this line
                        match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                        if match:
                            p_value_str = match.group(1)
                            try:
                                p_value = float(p_value_str)
                                if p_value < 0.05:
                                    # Write the protein name to the output file
                                    out_f.write(protein_name + '\n')
                                    print(f"{protein_name}: p-value {p_value} < 0.05, added to {output_file}")
                                else:
                                    print(f"{protein_name}: p-value {p_value} >= 0.05, not added")
                            except ValueError:
                                print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                        else:
                            print(f"{protein_name}: p-value not found in line: {line.strip()}")
                        # Break after processing the line
                        break
                else:
                    # If we didn't find the line with 'Likelihood ratio test...'
                    print(f"{protein_name}: 'Likelihood ratio test' line not found in {filename}")
# Out:
# 59463.ENSMLUP00000000083: p-value 0.5 >= 0.05, not added
# 59463.ENSMLUP00000001427: p-value 0.5 >= 0.05, not added
# 59463.ENSMLUP00000001789: p-value 0.5 >= 0.05, not added
# 59463.ENSMLUP00000002616: p-value 0.5 >= 0.05, not added
# 59463.ENSMLUP00000002847: p-value 0.4593 >= 0.05, not added
# 59463.ENSMLUP00000003315: p-value 0.5 >= 0.05, not added
# 59463.ENSMLUP00000003322: p-value 0.5 >= 0.05, not added
# 59463.ENSMLUP00000004009: p-value 0.3741 >= 0.05, not added
# 59463.ENSMLUP00000004202: p-value 0.2994 >= 0.05, not added
# 59463.ENSMLUP00000005054: 'Likelihood ratio test' line not found in 59463.ENSMLUP00000005054_bat_only_nucleotide_codon_aligned.fasta_busted.log
# 59463.ENSMLUP00000005366: p-value 0.2931 >= 0.05, not added
# 59463.ENSMLUP00000005595: p-value 0.2989 >= 0.05, not added
# 59463.ENSMLUP00000008027: p-value 0.5 >= 0.05, not added
# 59463.ENSMLUP00000009180: p-value 0.5 >= 0.05, not added
# 59463.ENSMLUP00000009404: 'Likelihood ratio test' line not found in 59463.ENSMLUP00000009404_bat_only_nucleotide_codon_aligned.fasta_busted.log
# 59463.ENSMLUP00000011160: 'Likelihood ratio test' line not found in 59463.ENSMLUP00000011160_bat_only_nucleotide_codon_aligned.fasta_busted.log

# %% [markdown]
# FDR

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'batecmreg_busted'

# Output file
output_file = 'batecmreg_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# NP_001159718.1: 'Likelihood ratio test' line not found or no p-value in NP_001159718.1_aligned_codon_alignment.fasta_busted.log
# NP_036597.1: 'Likelihood ratio test' line not found or no p-value in NP_036597.1_aligned_codon_alignment.fasta_busted.log
# NP_079279.3: 'Likelihood ratio test' line not found or no p-value in NP_079279.3_aligned_codon_alignment.fasta_busted.log
# NP_000005.2: raw p = 0.4814, FDR p = 0.5 (not significant)
# NP_000020.1: raw p = 0.2562, FDR p = 0.5 (not significant)
# NP_000053.2: raw p = 0.1706, FDR p = 0.5 (not significant)
# NP_000090.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000091.1: raw p = 0.129, FDR p = 0.5 (not significant)
# NP_000120.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000122.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000124.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000176.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000286.3: raw p = 0.0754, FDR p = 0.5 (not significant)
# NP_000292.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000293.2: raw p = 0.4834, FDR p = 0.5 (not significant)
# NP_000299.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000345.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000350.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000353.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000387.1: raw p = 0.4226, FDR p = 0.5 (not significant)
# NP_000403.1: raw p = 0.0017, FDR p = 0.07735 (not significant)
# NP_000479.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000495.1: raw p = 0.0262, FDR p = 0.431 (not significant)
# NP_000497.1: raw p = 0.3884, FDR p = 0.5 (not significant)
# NP_000593.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000615.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000884.1: raw p = 0, FDR p = 0 (SIGNIFICANT)
# NP_000908.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000921.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000925.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_000926.2: raw p = 0.1918, FDR p = 0.5 (not significant)
# NP_001001851.1: raw p = 0.4268, FDR p = 0.5 (not significant)
# NP_001001991.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001002235.1: raw p = 0.0748, FDR p = 0.5 (not significant)
# NP_001002236.1: raw p = 0.0748, FDR p = 0.5 (not significant)
# NP_001008693.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001012303.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001017962.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001017973.1: raw p = 0.1039, FDR p = 0.5 (not significant)
# NP_001017974.1: raw p = 0.1003, FDR p = 0.5 (not significant)
# NP_001027018.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001027019.1: raw p = 0.4578, FDR p = 0.5 (not significant)
# NP_001027466.1: raw p = 0.1733, FDR p = 0.5 (not significant)
# NP_001035237.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001035362.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001035983.1: raw p = 0.4406, FDR p = 0.5 (not significant)
# NP_001075.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001092010.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001094077.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001095886.1: raw p = 0.0296, FDR p = 0.431 (not significant)
# NP_001100.3: raw p = 0.4065, FDR p = 0.5 (not significant)
# NP_001101.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001107645.1: raw p = 0.4998, FDR p = 0.5 (not significant)
# NP_001116224.1: raw p = 0.4527, FDR p = 0.5 (not significant)
# NP_001116838.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001121167.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001121172.1: raw p = 0.0752, FDR p = 0.5 (not significant)
# NP_001121173.1: raw p = 0.0748, FDR p = 0.5 (not significant)
# NP_001121174.1: raw p = 0.075, FDR p = 0.5 (not significant)
# NP_001121175.1: raw p = 0.0753, FDR p = 0.5 (not significant)
# NP_001121176.1: raw p = 0.0749, FDR p = 0.5 (not significant)
# NP_001121177.1: raw p = 0.0749, FDR p = 0.5 (not significant)
# NP_001121178.1: raw p = 0.0749, FDR p = 0.5 (not significant)
# NP_001121179.1: raw p = 0.0748, FDR p = 0.5 (not significant)
# NP_001121363.1: raw p = 0.1729, FDR p = 0.5 (not significant)
# NP_001121676.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001121677.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001121678.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001127890.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001130000.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001130002.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001136067.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001136068.1: raw p = 0.0416, FDR p = 0.5 (not significant)
# NP_001136070.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001136071.1: raw p = 0.0181, FDR p = 0.3172 (not significant)
# NP_001138503.1: raw p = 0.4647, FDR p = 0.5 (not significant)
# NP_001138743.1: raw p = 0.1686, FDR p = 0.5 (not significant)
# NP_001138744.1: raw p = 0.1694, FDR p = 0.5 (not significant)
# NP_001138765.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001138767.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001138792.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001139761.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001153059.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001153060.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001155313.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001157961.1: raw p = 0.3958, FDR p = 0.5 (not significant)
# NP_001157962.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001159392.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001159393.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001159716.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001159717.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001159906.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001159907.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001159921.1: raw p = 0.0085, FDR p = 0.3094 (not significant)
# NP_001159923.1: raw p = 0.2222, FDR p = 0.5 (not significant)
# NP_001159970.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001161066.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001167515.1: raw p = 0.0001, FDR p = 0.006067 (SIGNIFICANT)
# NP_001167516.1: raw p = 0.0001, FDR p = 0.006067 (SIGNIFICANT)
# NP_001167517.1: raw p = 0.0001, FDR p = 0.006067 (SIGNIFICANT)
# NP_001171131.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001177411.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001182220.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001184026.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001184027.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001186668.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001186759.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001186958.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001186959.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001186960.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001186961.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001188504.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001191689.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001193943.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001226.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001230175.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001244900.1: raw p = 0.4042, FDR p = 0.5 (not significant)
# NP_001244901.1: raw p = 0.3579, FDR p = 0.5 (not significant)
# NP_001248393.1: raw p = 0.4583, FDR p = 0.5 (not significant)
# NP_001248759.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001248760.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001258751.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001258752.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001258753.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001258754.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001263419.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001268659.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001269376.1: raw p = 0.4884, FDR p = 0.5 (not significant)
# NP_001269604.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001271204.1: raw p = 0.2823, FDR p = 0.5 (not significant)
# NP_001271205.1: raw p = 0.2836, FDR p = 0.5 (not significant)
# NP_001275536.1: raw p = 0.4745, FDR p = 0.5 (not significant)
# NP_001275537.1: raw p = 0.4905, FDR p = 0.5 (not significant)
# NP_001275543.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001275961.1: raw p = 0.4146, FDR p = 0.5 (not significant)
# NP_001275962.1: raw p = 0.4164, FDR p = 0.5 (not significant)
# NP_001276093.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001276094.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001278207.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001278208.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001278238.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001313.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001314.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001324.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001325.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001326.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001327.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001624.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001747.2: raw p = 0.4954, FDR p = 0.5 (not significant)
# NP_001805.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001870.3: raw p = 0.4621, FDR p = 0.5 (not significant)
# NP_001889.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001890.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001891.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001900.1: raw p = 0.2305, FDR p = 0.5 (not significant)
# NP_001902.1: raw p = 0.2819, FDR p = 0.5 (not significant)
# NP_001903.1: raw p = 0.3498, FDR p = 0.5 (not significant)
# NP_001963.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001985.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002206.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002207.2: raw p = 0.3895, FDR p = 0.5 (not significant)
# NP_002209.2: raw p = 0.0002, FDR p = 0.0104 (SIGNIFICANT)
# NP_002308.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002309.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002413.1: raw p = 0.4262, FDR p = 0.5 (not significant)
# NP_002414.1: raw p = 0.1829, FDR p = 0.5 (not significant)
# NP_002415.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002417.2: raw p = 0.1192, FDR p = 0.5 (not significant)
# NP_002418.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002419.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002572.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002606.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002629.1: raw p = 0.0042, FDR p = 0.1699 (not significant)
# NP_002630.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002631.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002649.1: raw p = 0.3499, FDR p = 0.5 (not significant)
# NP_002760.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002761.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002762.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002763.2: raw p = 0.48, FDR p = 0.5 (not significant)
# NP_002766.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002965.1: raw p = 0.1254, FDR p = 0.5 (not significant)
# NP_003055.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_003108.2: raw p = 0.0001, FDR p = 0.006067 (SIGNIFICANT)
# NP_003236.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_003245.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_003246.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_003247.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_003540.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_003610.2: raw p = 0.0293, FDR p = 0.431 (not significant)
# NP_003764.3: raw p = 0.4348, FDR p = 0.5 (not significant)
# NP_003775.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_003784.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_003803.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_003804.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_003805.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_003806.3: raw p = 0.4804, FDR p = 0.5 (not significant)
# NP_003808.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_004070.3: raw p = 0.4261, FDR p = 0.5 (not significant)
# NP_004123.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_004146.1: raw p = 0.473, FDR p = 0.5 (not significant)
# NP_004190.1: raw p = 0.0183, FDR p = 0.3172 (not significant)
# NP_004236.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_004381.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_004521.1: raw p = 0.1725, FDR p = 0.5 (not significant)
# NP_004559.4: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_004762.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_004985.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_004986.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_005015.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_005016.1: raw p = 0.4527, FDR p = 0.5 (not significant)
# NP_005204.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_005483.1: raw p = 0.4626, FDR p = 0.5 (not significant)
# NP_005567.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_005568.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_005579.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_005738.4: raw p = 0.3399, FDR p = 0.5 (not significant)
# NP_005916.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_005932.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_006191.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_006206.2: raw p = 0.4149, FDR p = 0.5 (not significant)
# NP_006207.1: raw p = 0.4709, FDR p = 0.5 (not significant)
# NP_006208.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_006211.2: raw p = 0.0748, FDR p = 0.5 (not significant)
# NP_006601.2: raw p = 0.2912, FDR p = 0.5 (not significant)
# NP_006656.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_006681.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_008850.1: raw p = 0.3282, FDR p = 0.5 (not significant)
# NP_008914.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_008968.4: raw p = 0.1764, FDR p = 0.5 (not significant)
# NP_008969.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_031369.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_031378.1: raw p = 0.2849, FDR p = 0.5 (not significant)
# NP_036401.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_036529.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_036596.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_055058.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_055294.1: raw p = 0.1843, FDR p = 0.5 (not significant)
# NP_055509.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_055679.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_055985.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_056245.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_056933.2: raw p = 0.0135, FDR p = 0.3172 (not significant)
# NP_057239.4: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_057270.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_060662.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_060703.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_061325.1: raw p = 0.3127, FDR p = 0.5 (not significant)
# NP_061905.2: raw p = 0.4986, FDR p = 0.5 (not significant)
# NP_062562.1: raw p = 0.4703, FDR p = 0.5 (not significant)
# NP_064608.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_064714.2: raw p = 0.4999, FDR p = 0.5 (not significant)
# NP_067610.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_068367.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_068368.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_068573.2: raw p = 0.3273, FDR p = 0.5 (not significant)
# NP_068600.4: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_068755.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_068813.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_071356.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_071405.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_071751.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_071913.1: raw p = 0.0129, FDR p = 0.3172 (not significant)
# NP_079496.1: raw p = 0.4914, FDR p = 0.5 (not significant)
# NP_085046.5: raw p = 0.4294, FDR p = 0.5 (not significant)
# NP_109591.1: raw p = 0.1265, FDR p = 0.5 (not significant)
# NP_112191.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_112217.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_115587.6: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_115992.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_127509.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_149348.2: raw p = 0.0617, FDR p = 0.5 (not significant)
# NP_149349.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_150377.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_254275.1: raw p = 0.014, FDR p = 0.3172 (not significant)
# NP_443098.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_443187.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_444272.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_536723.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_542177.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_543020.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_570612.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_598000.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_598377.3: raw p = 0.2354, FDR p = 0.5 (not significant)
# NP_612140.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_620686.1: raw p = 0.4744, FDR p = 0.5 (not significant)
# NP_624302.1: raw p = 0.2142, FDR p = 0.5 (not significant)
# NP_631947.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_666023.1: raw p = 0.3581, FDR p = 0.5 (not significant)
# NP_671724.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_680475.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_694859.1: raw p = 0.0001, FDR p = 0.006067 (SIGNIFICANT)
# NP_694882.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_695013.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_695014.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_695015.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_695017.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_710159.1: raw p = 0.3323, FDR p = 0.5 (not significant)
# NP_776249.1: raw p = 0.1786, FDR p = 0.5 (not significant)
# NP_783866.2: raw p = 0.2827, FDR p = 0.5 (not significant)
# NP_808807.2: raw p = 0.2791, FDR p = 0.5 (not significant)
# NP_808808.1: raw p = 0.2788, FDR p = 0.5 (not significant)
# NP_878907.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_891550.1: raw p = 0.4733, FDR p = 0.5 (not significant)
# NP_922932.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_940912.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_940998.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_942130.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_945345.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_997077.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_997079.1: raw p = 0.4874, FDR p = 0.5 (not significant)
# NP_997080.1: raw p = 0.4941, FDR p = 0.5 (not significant)
# XP_005245479.1: raw p = 0.4995, FDR p = 0.5 (not significant)
# XP_005246699.1: raw p = 0.4707, FDR p = 0.5 (not significant)
# XP_005246989.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005248097.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005248716.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005249241.1: raw p = 0.4838, FDR p = 0.5 (not significant)
# XP_005249871.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005250295.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005251773.1: raw p = 0.3575, FDR p = 0.5 (not significant)
# XP_005256758.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005258332.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005259574.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005260515.1: raw p = 0.3124, FDR p = 0.5 (not significant)
# XP_005260696.1: raw p = 0.4467, FDR p = 0.5 (not significant)
# XP_005261654.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005265386.1: raw p = 0.3169, FDR p = 0.5 (not significant)
# XP_005265581.1: raw p = 0.0621, FDR p = 0.5 (not significant)
# XP_005265582.1: raw p = 0.0626, FDR p = 0.5 (not significant)
# XP_005266060.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005266835.1: raw p = 0.0293, FDR p = 0.431 (not significant)
# XP_005267408.1: raw p = 0.1726, FDR p = 0.5 (not significant)
# XP_005267790.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005268208.1: raw p = 0.4017, FDR p = 0.5 (not significant)
# XP_005268209.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005268355.1: raw p = 0.0525, FDR p = 0.5 (not significant)
# XP_005269337.1: raw p = 0.2783, FDR p = 0.5 (not significant)
# XP_005270250.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005272173.1: raw p = 0.0174, FDR p = 0.3172 (not significant)
# XP_005272174.1: raw p = 0.0182, FDR p = 0.3172 (not significant)
# XP_005272175.1: raw p = 0.0181, FDR p = 0.3172 (not significant)
# XP_005272176.1: raw p = 0.0177, FDR p = 0.3172 (not significant)
# XP_005272177.1: raw p = 0.0183, FDR p = 0.3172 (not significant)
# XP_005272294.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005272296.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005272702.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_005273727.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_006713720.1: raw p = 0.4515, FDR p = 0.5 (not significant)
# XP_006713764.1: raw p = 0.4245, FDR p = 0.5 (not significant)
# XP_006714791.1: raw p = 0.018, FDR p = 0.3172 (not significant)
# XP_006714792.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_006714793.1: raw p = 0.1003, FDR p = 0.5 (not significant)
# XP_006715071.1: raw p = 0.1266, FDR p = 0.5 (not significant)
# XP_006715073.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_006717023.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_006717400.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_006718790.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_006718791.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_006718792.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_006718821.1: raw p = 0.1668, FDR p = 0.5 (not significant)
# XP_006720222.1: raw p = 0.4996, FDR p = 0.5 (not significant)
# XP_006722625.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_006723893.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_006725226.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_006725227.1: raw p = 0.4999, FDR p = 0.5 (not significant)
# XP_006725460.1: raw p = 0.5, FDR p = 0.5 (not significant)

# %% [markdown]
# EXAMINATION OF FITMG94 and R part
